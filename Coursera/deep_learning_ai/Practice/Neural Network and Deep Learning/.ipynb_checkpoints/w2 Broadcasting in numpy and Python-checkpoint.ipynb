# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

A = np.array([[56.0,0.0,4.4,68.0],
              [1.2, 104, 0.52, 0, 8.0],
              [1.8, 135, 0.99, 0.9]]).astype()

print(A)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-5ccea6c54c4e> in <module>
#       3 A = np.array([[56.0,0.0,4.4,68.0],
#       4               [1.2, 104, 0.52, 0, 8.0],
# ----> 5               [1.8, 135, 0.99, 0.9]]).astype()
#       6
#       7 print(A)
#
# TypeError: astype() missing required argument 'dtype' (pos 1)

# %% [markdown]
# sum vertically using axis=0

# %%
print(A.sum(axis=0))
# Out:
# [56.0, 0.0, 4.4, 68.0, 1.2, 104, 0.52, 0, 8.0, 1.8, 135, 0.99, 0.9]
