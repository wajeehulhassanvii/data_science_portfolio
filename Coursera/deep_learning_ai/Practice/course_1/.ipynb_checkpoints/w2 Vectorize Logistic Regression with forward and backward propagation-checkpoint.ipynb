# %%
import numpy as np

# %% [markdown]
# ## FORWARD PROPAGATION

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## BACKWARD PROPAGATION

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # IMPLEMENTATION OF LOGISTIC REGRESSION

# %% [markdown]
# ![image.png](attachment:image.png)
