# %% [markdown]
# ## LAB 1. EXPLORE DATA WITH BIGQUERY AND JUPYTERLAB

# %% [markdown]
# ##### GCP notebook

# %% [markdown]
# open GCP and create a notebook from 'AI platform' tab

# %% [markdown]
# ##### GCP BigQuery

# %% [markdown]
# then create a BigQuery sheet and run the command

# %% [markdown]
# ##### bigquery have public data, we will use 'natality' table, run below BIGQUERY statement

# %% [markdown]
# SELECT
#   plurality,
#   COUNT(1) AS num_babies,
#   AVG(weight_pounds) AS avg_wt
#  FROM
#   publicdata.samples.natality
#  WHERE
#   year > 2000 AND year < 2005
#  GROUP BY
#   plurality

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# How many triplets were born in the US between 2000 and 2005? ___________

# %% [markdown]
# 27697 triplets were born between 2000 and 2005

# %% [markdown]
# ##### switch to jupyter notebook and run the following command in a new notebook

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### written query

# %% [markdown]
# query="""
# SELECT
#     weight_pounds,
#     is_male,
#     mother_age,
#     plurality,
#     gestation_weeks
# FROM
#     publicdata.samples.natality
# WHERE year > 2000
# """
# from google.cloud import bigquery
# df = bigquery.Client().query(query + "LIMIT 100").to_dataframe()
# df.head()

# %% [markdown]
# ##### we get the following result

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Finding if male babies are weighted heigher or not in jupyterlab

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# def get_district_values(column_name):
#     sql="""
# SELECT
#     {0},
#     COUNT(1) AS num_babies,
#     AVG(weight_pounds) AS avg_wt
# FROM
#     publicdata.samples.natality
# WHERE
#     year > 2000
# GROUP BY
#     {0}
#     """.format(column_name)
#     return bigquery.Client().query(sql).to_dataframe()
#
# df = get_district_values('is_male')
# df.plot(x="is_male", y='avg_wt', kind='bar')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# It can be seen that male babies are slightly higher in weight.

# %% [markdown]
# ##### next

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# df = get_distinct_values('gestation_weeks')
# df = df.sort_values('gestation_weeks')
# df.plot(x='gestation_weeks', y='avg_wt', kind='bar')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This graph shows the average weight of babies born in the each week of pregancy. The way you'd read the graph is to look at the y-value for x=35 to find out the average weight of a baby born in the 35th week of pregnancy.
#
# Is gestation_weeks a good feature to use in our machine learning model? _____
#
# Is gestation_weeks always available? __________
#
# Compare the variability of birth weight due to sex of baby and due to gestation weeks. Which factor do you think is more important for accurate weight prediction?

# %% [markdown]
# yes, gestation_weeks looks like a reasonable feature to be used in machine learning models

# %% [markdown]
# Gestation_weeks is only available after the 17th week and till the 47th/48th week.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## LAB 2. CREATING A SAMPLED DATASET

# %% [markdown]
# Clone a git repo, by following below method

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# clone the following repo:<br>https://github.com/GoogleCloudPlatform/training-data-analyst/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### after cloning we get this  folder on the top left

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### run the  notebook in jupyterlab
# training-data-analyst/courses/machine_learning/deepdive/06_structured/2_sample.ipynb

# %% [markdown]
# ##### change the bucket, project and region, then run all the cells

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
BUCKET = 'try_gcp_bucket_1'
PROJECT = 'alpine-land-169002 '
REGION = 'australia-southeast1'

# %% [markdown]
# ##### try_gcp_bucket_1 i newly created bucket
# project is the project id, created initially,
# we choose the region ourself to start a project and bucket, in this case our bucket is only present in our defined region and not in multi-region

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## CREATE KERAS DNN AND WIDE-AND-DEEP MODEL

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## CLOUD DATAFLOW FOR DATA PREPROCESSING

# %% [markdown]
# ![image.png](attachment:image.png)
