# %% [markdown]
# ### Working with estimator APIs

# %% [markdown]
# ##### Set up machine learning model
# 1. Regression or classification
# 2. What is the label?
# 3. What are the features?

# %% [markdown]
# ##### Carry out ML steps
# 1. Train the model
# 2. Evaluate the model
# 3. Predict the model

# %% [markdown]
# ![Screenshot%20from%202020-07-07%2002-35-45.png](attachment:Screenshot%20from%202020-07-07%2002-35-45.png)

# %% [markdown]
# here we created tensorflow numeric feature list, which is only one in this case "sq_footage"

# %% [markdown]
# ##### train on function, which will hold larger dataset in memory. Eg:
# model.train(train_input_fn, steps=100)

# %% [markdown]
# 100 steps of gradient descent and train_input_fn will be the function

# %% [markdown]
# after training we can simply predict from the model

# %% [markdown]
# ##### we can predict with both, features and functions

# %% [markdown]
# ### creating categorical columns

# %% [markdown]
# ![Screenshot%20from%202020-07-07%2002-41-19.png](attachment:Screenshot%20from%202020-07-07%2002-41-19.png)

# %% [markdown]
# #### decoding the CSV

# %% [markdown]
# ![Screenshot%20from%202020-07-07%2002-55-13.png](attachment:Screenshot%20from%202020-07-07%2002-55-13.png)

# %% [markdown]
# ![Screenshot%20from%202020-07-07%2002-57-19.png](attachment:Screenshot%20from%202020-07-07%2002-57-19.png)

# %% [markdown]
# ![Screenshot%20from%202020-07-07%2002-59-24.png](attachment:Screenshot%20from%202020-07-07%2002-59-24.png)

# %% [markdown]
# train_and_evaluate function is helpful as it takes care of the stack on the right hand side

# %% [markdown]
# ![Screenshot%20from%202020-07-07%2003-00-43.png](attachment:Screenshot%20from%202020-07-07%2003-00-43.png)
