# %% [markdown]
# wide and deep model works best on structured data

# %% [markdown]
# ![Screenshot%20from%202020-07-07%2003-11-26.png](attachment:Screenshot%20from%202020-07-07%2003-11-26.png)

# %% [markdown]
# price and waitTimes are dense features, continuous

# %% [markdown]
# with increase in price customer satisfaction goes down

# %% [markdown]
# as waitTime increases customer satisfaction goes down

# %% [markdown]
# employeeID is not a numeric feature, its a sparse feature

# %% [markdown]
# DNNs work well when features are dense and highly correlated

# %% [markdown]
# ![Screenshot%20from%202020-07-07%2003-14-14.png](attachment:Screenshot%20from%202020-07-07%2003-14-14.png)

# %% [markdown]
# ![Screenshot%20from%202020-07-07%2003-21-59.png](attachment:Screenshot%20from%202020-07-07%2003-21-59.png)

# %% [markdown]
# in sparse dataset linear models perform better, DNNs don't, since they aren't correlated

# %% [markdown]
# ![Screenshot%20from%202020-07-07%2003-23-33.png](attachment:Screenshot%20from%202020-07-07%2003-23-33.png)

# %% [markdown]
# we use linear model for sparse and wide model for correlated features, but wide and deep model works best for both, we take sparse and connect it directly to the output

# %% [markdown]
# takse sparse and conenct them to output directly, then take dense passs through multiple layers then send it to o/p, combined is calkled wide and deep model

# %% [markdown]
# wide and deep model takes two input features list
