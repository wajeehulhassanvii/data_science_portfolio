# %% [markdown]
# ##### the most common ML models at Google are operating on structured data

# %% [markdown]
# ![Screenshot%20from%202020-07-06%2022-24-01.png](attachment:Screenshot%20from%202020-07-06%2022-24-01.png)

# %% [markdown]
# MLPs 4/5 layers multilayer perceptrons

# %% [markdown]
# LSTM -> text and timeseries

# %% [markdown]
# CNNs -> text and images
